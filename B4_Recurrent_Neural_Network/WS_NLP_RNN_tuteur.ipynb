# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Compétences-du-Workshop" data-toc-modified-id="Compétences-du-Workshop-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Compétences du Workshop</a></span></li><li><span><a href="#Objectifs" data-toc-modified-id="Objectifs-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Objectifs</a></span></li><li><span><a href="#Philosophie-et-recommandations" data-toc-modified-id="Philosophie-et-recommandations-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Philosophie et recommandations</a></span></li><li><span><a href="#Prétraitement-et-préparation-de-l'environnement" data-toc-modified-id="Prétraitement-et-préparation-de-l'environnement-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>Prétraitement et préparation de l'environnement</a></span><ul class="toc-item"><li><span><a href="#Nettoyage-des-tweets" data-toc-modified-id="Nettoyage-des-tweets-4.1"><span class="toc-item-num">4.1&nbsp;&nbsp;</span>Nettoyage des tweets</a></span></li><li><span><a href="#Tokénisation-ou-segmentation" data-toc-modified-id="Tokénisation-ou-segmentation-4.2"><span class="toc-item-num">4.2&nbsp;&nbsp;</span>Tokénisation ou segmentation</a></span></li><li><span><a href="#Word-Embedding:-convertir-un-document-en-une-matrice-de-nombres" data-toc-modified-id="Word-Embedding:-convertir-un-document-en-une-matrice-de-nombres-4.3"><span class="toc-item-num">4.3&nbsp;&nbsp;</span>Word Embedding: convertir un document en une matrice de nombres</a></span></li><li><span><a href="#Préparation-du-pipeline" data-toc-modified-id="Préparation-du-pipeline-4.4"><span class="toc-item-num">4.4&nbsp;&nbsp;</span>Préparation du pipeline</a></span></li></ul></li><li><span><a href="#Entraînement-du-modèle" data-toc-modified-id="Entraînement-du-modèle-5"><span class="toc-item-num">5&nbsp;&nbsp;</span>Entraînement du modèle</a></span><ul class="toc-item"><li><span><a href="#RNN:-Réseaux-de-neurones-réccurents-simples" data-toc-modified-id="RNN:-Réseaux-de-neurones-réccurents-simples-5.1"><span class="toc-item-num">5.1&nbsp;&nbsp;</span>RNN: Réseaux de neurones réccurents simples</a></span></li><li><span><a href="#GRU:-Gated-Recurrent-Units" data-toc-modified-id="GRU:-Gated-Recurrent-Units-5.2"><span class="toc-item-num">5.2&nbsp;&nbsp;</span>GRU: Gated Recurrent Units</a></span></li><li><span><a href="#LSTM" data-toc-modified-id="LSTM-5.3"><span class="toc-item-num">5.3&nbsp;&nbsp;</span>LSTM</a></span></li></ul></li><li><span><a href="#Évaluation-des-performances-des-modèles" data-toc-modified-id="Évaluation-des-performances-des-modèles-6"><span class="toc-item-num">6&nbsp;&nbsp;</span>Évaluation des performances des modèles</a></span><ul class="toc-item"><li><span><a href="#Evaluation-des-modèles-par-le-dataset-test" data-toc-modified-id="Evaluation-des-modèles-par-le-dataset-test-6.1"><span class="toc-item-num">6.1&nbsp;&nbsp;</span>Evaluation des modèles par le dataset test</a></span></li><li><span><a href="#Évaluation-des-résultats-du-LSTM" data-toc-modified-id="Évaluation-des-résultats-du-LSTM-6.2"><span class="toc-item-num">6.2&nbsp;&nbsp;</span>Évaluation des résultats du LSTM</a></span></li><li><span><a href="#Pour-aller-plus-loin-avec-NLP" data-toc-modified-id="Pour-aller-plus-loin-avec-NLP-6.3"><span class="toc-item-num">6.3&nbsp;&nbsp;</span>Pour aller plus loin avec NLP</a></span></li></ul></li></ul></div>

# %% [markdown]
# # Traitement du langage naturel et classification par Réseaux de Neurones Récurrents (RNNs)
#
# ![GPI-CESI.jpg](attachment:GPI-CESI.jpg)
#
# <table>
# <thead>
#   <tr><th>Auteur</th><th>Relecteur</th><th>Centre</th><th>Modification</th>
# </thead>
# <tbody>
#   <tr><td>Genane YOUNESS</td><td>Benjamin COHEN BOULAKIA</td><td>Nanterre</td><td>2023-02-07</td></tr>
# </tbody>
# </table>

# %% [markdown]
# <blockquote>
#     <h1><center>Guide tuteur</center></h1>
#
# <h2>Compétences du Workshop</h2>
# <ul>
#     <li><u>Modéliser</u> les données du langage naturel sous la forme d'information pour un problème concret.</li>
#     <li><u>Présenter</u> les implémentations des différentes étapes du traitement de langage naturel. </li>
#     <li><u>Réaliser</u> un programme permettant de trouver l'analyse de sentiment modélisé par des réseaux de neurones récurrents. </li>
#     <li><u>Sélectionner</u> les structures de données les plus efficaces en terme de performance.</li>
#     </ul>
#
# <h2>Objectifs</h2>
#
# Ce Workshop va permettre aux étudiants de répondre, en partie, à la problématique des réseaux de neurones récurrents de l'option Data Science. Il vise à acquérir les concepts de base du traitement du langage naturel (NLP) et à construire un modèle de classification binaire avec des réseaux de neurones récurrents (RNN). La première partie porte sur le nettoyage des données de Twitter. La deuxième partie doit les amener à réfléchir à ce qu'est le word embedding et à déterminer une représentation de chaque mot par une liste de nombres incorporant le "sens" de ce mot. Il s'agit notamment de comprendre l'utilisation de la technique GloVe (Global Vectors for Word Representation). La dernière partie traite de l'entraînement du modèle par les réseaux de neurones GRU et LSTM.
#
# <h2>Philosophie et recommandations</h2>
#
# Le but de ce workshop est d'aborder le principe de TAL et de faire une analyse des tweets par les réseaux de neurones récurrents. Certains réseaux neuronaux sont plus efficaces que d'autres mais nécessitent plus de temps de calcul en raison du nombre élevé de paramètres. Les étudiants doivent être encouragés à essayer différentes architectures et types de réseaux de neurones dans leur projet.
# Par ailleurs, de nombreuses questions sont posées dans ce Workshop qui sont liées à des aspects scientifiques, d'autres fournissent des indications importantes sur la solution de certains problèmes, il est donc important d'amener au débat ces questions
# Enfin, ce Workshop utilise un certain nombre de dataset et de bases de données externes, il est recommandé aux étudiants de parcourir l'ensemble du Workshop en amont, et de télécharger ces données avant le lancement de la séance, pour gagner du temps.
# </blockquote>

# %% [markdown]
# L'objectif de de ce Workshop est de vous faire acquérir les notions de base du [traitement du langage naturel ou NLP (Natural Langage Processing)](https://lbourdois.github.io/blog/nlp/) et de construire un modèle de classification binaire avec les réseaux de neurones récurrents (RNNs).
#
# Contrairement aux réseaux de neurones traditionnels, les réseaux de neurones récurrents s'étendent dans les séquences spatiales et temporelles. En d'autres termes, les couches cachées du moment présent et du moment suivant sont liées.
# L'application que vous allez effectuer consiste à construire un modèle pour identifier les publications Twitter (« tweets ») qui annoncent une catastrophe. Cet apprentissage fait parti du traitement du langage naturel, NLP.
# Cette classification de texte binaire est importante, car elle pourrait aider les agences de l'État à identifier rapidement les catastrophes et à y répondre.
# Les données disponibles sont les tweets étiquetés signalant une catastrophe ou non.
# Au premier lieu, nous allons faire le nettoyage des données textuelles avant de passer à la classification binaire avec RNN.
#
# Le dataset utilisé dans ce Workshop est celui du challenge Kaggle [_Natural Language Processing with Disaster Tweets_](https://www.kaggle.com/competitions/nlp-getting-started/data). Ce dataset vous est fourni dans une archive <code>nlp-getting-started.zip</code>, décompressez son contenu dans un répertoire <code>nlp-getting-started</code> que vous placerez dans le même répertoire que ce Workshop.

# %% [markdown]
# ##  Prétraitement et préparation de l'environnement

# %%
import numpy as np
import pandas as pd
import tensorflow as tf
import keras

import matplotlib.pyplot as plt
# Out:
# WARNING:tensorflow:From c:\Users\gbencheikh\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.

# %% [markdown]
# Nous commençons par télécharger les publications Twitter (« tweets »). Nous récupérons les colonnes qui nous intéressent, ce sont les colonnes <code>textes</code> et <code>target</code>. Le texte est une phrase ou tweet de type _text_, et le _target_ est de type _int64_ étiqueté <code>1</code> pour catastrophe, <code>0</code> sinon.

# %%
import zipfile

with zipfile.ZipFile('nlp-getting-started.zip', 'r') as zip_ref:
    zip_ref.extractall('.')

# %%
import os

# Changez selon le chemin de votre téléchargement du dataset
# os.chdir('nlp-getting-started')
train_data = pd.read_csv('train.csv', usecols=['text', 'target'], dtype={'text': str, 'target': np.int64})

train_data.shape
# Out:
# (7613, 2)

# %%
train_data.head(20)
# Out:
#                                                  text  target
# 0   Our Deeds are the Reason of this #earthquake M...       1
# 1              Forest fire near La Ronge Sask. Canada       1
# 2   All residents asked to 'shelter in place' are ...       1
# 3   13,000 people receive #wildfires evacuation or...       1
# 4   Just got sent this photo from Ruby #Alaska as ...       1
# 5   #RockyFire Update => California Hwy. 20 closed...       1
# 6   #flood #disaster Heavy rain causes flash flood...       1
# 7   I'm on top of the hill and I can see a fire in...       1
# 8   There's an emergency evacuation happening now ...       1
# 9   I'm afraid that the tornado is coming to our a...       1
# 10        Three people died from the heat wave so far       1
# 11  Haha South Tampa is getting flooded hah- WAIT ...       1
# 12  #raining #flooding #Florida #TampaBay #Tampa 1...       1
# 13            #Flood in Bago Myanmar #We arrived Bago       1
# 14  Damage to school bus on 80 in multi car crash ...       1
# 15                                     What's up man?       0
# 16                                      I love fruits       0
# 17                                   Summer is lovely       0
# 18                                  My car is so fast       0
# 19                       What a goooooooaaaaaal!!!!!!       0

# %% [markdown]
# Nous allons télécharger aussi les données test pour évaluer la performance du modèle de classification.

# %%
test_data =\
    pd.read_csv('test.csv', usecols=['text', 'id'],   dtype={'text': str, 'id': np.int64}) #SOLUTION

# %% [markdown]
# Visualisons les premiers textes :

# %%
train_data['text'].head().values
# Out:
# array(['Our Deeds are the Reason of this #earthquake May ALLAH Forgive us all',
#        'Forest fire near La Ronge Sask. Canada',
#        "All residents asked to 'shelter in place' are being notified by officers. No other evacuation or shelter in place orders are expected",
#        '13,000 people receive #wildfires evacuation orders in California ',
#        'Just got sent this photo from Ruby #Alaska as smoke from #wildfires pours into a school '],
#       dtype=object)

# %% [markdown]
# Certaines données sont mal étiquetées, nous allons les éliminer du Dataset (Pour plus de détails sur ces tweets, consultez les [travaux de Dmitri Kalyaevs](https://www.kaggle.com/code/dmitri9149/transformer-svm-semantically-identical-tweets/notebook)).

# %%
train_data=train_data.drop(train_data.index[[4415, 4400, 4399,4403,4397,4396, 4394,4414, 4393,4392,4404,4407,4420,
                                             4412,4408,4391,4405,6840,6834,6837,6841,6816,6828,6831,601,576,584,608,
                                             606,603,592,604,591, 587,3913,3914,3936,3921,3941,3937,3938,3136,3133,
                                             3930,3933,3924,3917,246,270,266,259,253,251,250,271,6119,6122,6123,6131,
                                             6160,6166,6167,6172,6212,6221,6230,6091,6108,7435,7460,7464,7466,7469,
                                             7475,7489,7495,7500,7525,7552,7572,7591,7599]])

# Distribution des classes
print(train_data.target.value_counts())
# Out:
# 0    4308
# 1    3223
# Name: target, dtype: int64

# %% [markdown]
# ### Nettoyage des tweets
#
# Comme pour tous les ensembles de données, les données de langage naturel comme les tweets nécessitent beaucoup de nettoyage. Cette étape fait partie de ce que nous appelons le prétraitement. À votre avis, en quoi consiste le nettoyage des tweets ? Quels sont les éléments qui doivent être supprimés pour que les tweets soient prêts pour la phase d'entraînement ?
#
# <blockquote>
# <strong style="text-decoration:underline;display:block">Solution</strong>
#
# Voici quelques étapes de nettoyage courantes :
#
# - **Suppression du bruit:** Il faut supprimer les éléments qui ont peu de signification comme les URL et les tags HTML dans le texte.
# - **Suppression de la ponctuation:** très facile avec les [RegEx]((https://www.w3schools.com/python/python_regex.asp), bien que le Tokenizer de Tensorflow le fasse par défaut.
# - **Suppression de stopwords:** Certains mots comme "a", "the" et "are" sont très courants et ont peu de signification dans une phrase. Leur suppression accélère l'apprentissage et améliore la précision.
# - **Stemming ou racinisation:** Le Stemming désigne généralement le processus heuristique brut qui consiste à couper la fin des mots afin de ne garder que la racine du mot. Exemple : "trouverez" →  "trouv".
# - **lemmatisation:** De nombreux mots sont dérivés d'une racine ou d'un mot-racine. Par exemple, des mots comme "travailler" et "travaillé" proviennent du mot "travail". Le remplacement de tous les mots par leur racine peut aider dans certaines tâches.
# - **Suppression des emojis :** Pour cela il faut un [module Python spécial](https://unicode.org/emoji/charts/full-emoji-list.html).
# - **Remplacement des lettres majuscules en minuscules :**
# - **Suppression des caractères spéciaux :** très facile avec les RegEx mais tous les caractères ne seront pas retirés dans un premier temps.
# - **Suppression des chiffres inutiles :** avec une RegEx
# </blockquote>
#
# Tout d'abord, nous allons procéder à la mise en place des pipelines : Préparation des bibliothèques et des outils pour le nettoyage des tweets. Nous utilisons Le _NLTK_ , ou Natural Language Toolkit, qui est l'une des bibliothèques de traitement du langage naturel les plus puissantes, conçue pour le traitement naturel symbolique et statistique de la langue en Python. Nous l'utilisons pour la tokenisation, le stemming, la lemmatisation et pour le chargement des stopwords. Il faudra d'ailleurs télécharger quelques bases de données de tokenizer préconstruits pour cela ([Punkt](https://www.nltk.org/api/nltk.tokenize.punkt.html) et OMW...).
#
# Voilà à quoi ressemble notre pipeline :

# %%
# Préparation des libraries et des outils pour le nettoyage des tweets
# Expressions régulières
import re
# Ponctuactions
import string

#Tokénisation
import nltk
nltk.download('punkt')
nltk.download('omw-1.4')
from nltk.tokenize import word_tokenize

# Lemmatisation
nltk.download('wordnet')

from nltk.stem import WordNetLemmatizer
lem=WordNetLemmatizer()

# Charger les stopwords

nltk.download('stopwords')
from nltk.corpus import stopwords


# Charger Le stemming qui consiste à réduire un mot dans sa forme “racine”
from nltk.stem import SnowballStemmer
stemmer = SnowballStemmer('english')
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\benco\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package omw-1.4 to
# [nltk_data]     C:\Users\benco\AppData\Roaming\nltk_data...
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\benco\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\benco\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %% [markdown]
# Nous allons commencer à écrire une fonction pour retirer les espaces vides, les chiffres, remplacer les caractères majuscules par des caractères minuscules, et retirer les caractères spéciaux. Pour cela, nous allons utiliser des _RegEx_ ou expression régulière, qui est une séquence de caractères qui forme un modèle de recherche. Pour avoir plus de détail, consultez  https://www.w3schools.com/python/python_regex.asp ou https://docs.python.org/fr/3/howto/regex.html
#
# <blockquote class="comment">
# <strong style="text-decoration:underline;display:block">Explications</strong>
# Cette partie peut être fournie aux groupes qui ne sont pas très à l'aise, afin de leur laisser plus de temps pour la partie suivante, qui doit absolument être traitée sans donner la correction aux élèves.
# </blockquote>

# %%
# Fonction pour le nettoyage de chaque document: nlp_pipeline
# Tweet= corpus de tweet = document
# Une RegEx, ou expression régulière, est une séquence de caractères qui forme un modèle de recherche.
def nlp_pipeline(text):
    # Convertir les lettres majuscules en minuscules
    text = text.lower()
    
    # Remplacer la nouvelle ligne par un espace
    text = text.replace('\n', ' ').replace('\r', '')
    text = ' '.join(text.split())
    
    # Retirer les lettres majuscules, toutes les chaine de caractères qui ne sont pas des lettres ou des chiffres
    text = re.sub(r"[A-Za-z\.]*[0-9]+[A-Za-z%°\.]*", "", text) #SOLUTION
    
    # Retirer les caractères spéciaux
    text = re.sub(r"(\s\-\s|-$)", "", text)       
    text = re.sub(r"[,\!\?\%\(\)\/\"]", "", text) #SOLUTION
    text = re.sub(r"\&\S*\s", "", text)           #SOLUTION
    text = re.sub(r"\&", "", text)                #SOLUTION
    text = re.sub(r"\+", "", text)                #SOLUTION
    text = re.sub(r"\#", "", text)                #SOLUTION
    text = re.sub(r"\$", "", text)                #SOLUTION
    text = re.sub(r"\£", "", text)                #SOLUTION
    text = re.sub(r"\%", "", text)                #SOLUTION
    text = re.sub(r"\:", "", text)                #SOLUTION
    text = re.sub(r"\@", "", text)                #SOLUTION
    text = re.sub(r"\-", "", text)                #SOLUTION
    text = re.sub(r"\'", "", text)                #SOLUTION
    text = re.sub(r"\x89û", "", text)
    return text

# %% [markdown]
# Parmi les étapes importantes du nettoyage des tweets figure la suppression des URLs et les tag HTML.Nous allons utiliser ensuite, le _stemming_ qui permet de supprimer la fin du mot et de ne conserver que de leur racine.

# %%
# Retirer les https
def remove_url(sentence):
    url = re.compile(r'https?://\S+|www\.\S+')
    return url.sub(r'', sentence)

def remove_html(sentence):
    html = re.compile(r'<.*?>')
    return html.sub(r'', sentence)

#Stemming: le stemming permet de supprimer la fin du mot et de ne conserver que la racine du mot. 
# Exemple: "trouvez" devient "trouv"
stemmer = SnowballStemmer('english')

def stem_words(sentence):
    words = sentence.split()
    words = [stemmer.stem(word) for word in words ]
    
    return ' '.join(words)

# Appliquer le stemming sur le mot "fired"
print(stemmer.stem('fired'))

# Appliquer le stemming sur le mot "emergency"
print(stemmer.stem('emergency'))
# Out:
# fire
# emerg

# %% [markdown]
# Utilisez la doc du module [stopword](https://pythonspot.com/nltk-stop-words/) pour trouver ces mots dans la langue anglaise, puis supprimez-les.

# %%
mots_vides= \
    set(stopwords.words('english')) #SOLUTION
print('\n')
print(mots_vides)
# Out:
# {'after', 'haven', "weren't", 'mustn', 'myself', 'aren', 'ma', 'its', 'some', 'doesn', 'ours', 'ourselves', 'theirs', 'do', 'if', 'too', 'that', 'further', 'being', 'but', 'and', "should've", 'can', 'ain', 'doing', 'under', 'few', 'he', 'of', 'them', 'up', 'wasn', 'through', 'what', 'again', 've', 'has', 'for', 'shan', "you'll", 'was', 'other', "hadn't", 'who', 'a', 'before', 'am', "wouldn't", 'only', 'in', 'should', 'shouldn', 't', 'i', 'when', 'm', 'not', 'below', 'll', 'him', 'my', 'didn', 'she', 'were', 'where', 'their', "you've", 'than', 'been', 'at', 'hasn', 'why', "it's", 'itself', 'does', 'such', "aren't", "needn't", 'won', 'couldn', 'is', 'now', 'to', 'because', 'you', 'above', 'y', 'o', 'then', 'by', 'they', 'most', 'here', 'no', "you're", "she's", 'which', 'isn', 'our', 're', 'nor', 'same', 'themselves', 'over', 'or', 'don', 'while', "isn't", 'had', 'his', 'himself', 'me', 'each', 'be', "shan't", "hasn't", 'those', 'more', "shouldn't", 'are', 'the', "mightn't", 'until', 'yours', 'having', 'from', 'weren', 'it', 'down', 'out', 'how', 'on', 'so', 'these', 'both', 'we', 'will', 'just', 'during', 'there', 'hadn', 'off', 'whom', 'between', 'own', 'herself', "don't", "couldn't", 'all', "mustn't", 'wouldn', "you'd", 'with', 'did', 'needn', 'about', 'any', 's', "that'll", 'have', 'mightn', "haven't", "won't", 'hers', 'her', 'your', 'd', 'this', 'against', 'into', "wasn't", 'as', 'an', 'yourselves', 'once', 'very', "doesn't", 'yourself', "didn't"}

# %%
# Fonction qui supprime les stopwords: les mots très courants dans la langues étudiée et qui n'apportent pas un sens. 
# comme en français, les mots: et, à,le, la, etc.. (https://pythonspot.com/nltk-stop-words/ )
mots_vides=stopwords.words('english')

def remove_stopwords(sentence):
    words = sentence.split()
    words =\
      [word for word in words if word not in mots_vides]#SOLUTION
    
    return ' '.join(words)

# %% [markdown]
# Observez les ponctuations en utilisant [string](https://docs.python.org/3/library/string.html) puis supprimez-les. Pour le faire, nous vous recommandons de chercher sur le mot _punctuation_ par mot clé sur la page.

# %%
ponctuations =\
    list(string.punctuation) #SOLUTION
print(ponctuations)
# Out:
# ['!', '"', '#', '$', '%', '&', "'", '(', ')', '*', '+', ',', '-', '.', '/', ':', ';', '<', '=', '>', '?', '@', '[', '\\', ']', '^', '_', '`', '{', '|', '}', '~']

# %%
# Supprimez les ponctuations
def remove_ponctuation(sentence):
    words = sentence.split() #SOLUTION
 
    words =\
        [char for char in words if not (char in ponctuations)] #SOLUTION
  
    return ' '.join(words)

# %% [markdown]
# Supprimez les emojis utilisées dans les tweets.
#
# Notons que les différents types d'éléments pictographiques sont souvent contigus dans l'encodage UTF, et qu'on devrait pouvoir en tirer parti dans la RegEx. Chaque emoji a un Unicode unique qui lui est attribué. Lorsque vous utilisez l'Unicode avec Python, remplacez "+" par "000" de l'Unicode. Et préfixez ensuite l'Unicode avec "\". Par exemple, U+1F605 sera utilisé comme \U0001F605. Ici, "+" est remplacé par "000" et "\" est préfixé par l'Unicode.

# %%
# Supprimez les emojis
def remove_emoji(sentence):
    emoji_pattern = re.compile("["
                                # emoticons
                           u"\U0001F600-\U0001F64F" 
                               # symbols & pictographs
                           u"\U0001F300-\U0001F5FF"    #SOLUTION
                                # transport & map symbols
                           u"\U0001F680-\U0001F6FF"  #SOLUTION
                               # flags (iOS) 
                           u"\U0001F1E0-\U0001F1FF"  #SOLUTION 
                           u"\U00002702-\U000027B0"  
                           u"\U000024C2-\U0001F251"
                           "]+", flags=re.UNICODE)
    
    return emoji_pattern.sub(r'', sentence)

# %% [markdown]
# Écrivez une fonction permettant de supprimer les terminaisons et d'isoler la forme canonique du mot, aussi connue sous le nom de lemme, et qui est souvent son [radical](https://www.espacefrancais.com/radicaux-prefixes-et-suffixes/), mais pas systématiquement. Notamment, dans le cas des verbes, qui doivent être passés à l'infinitif. Par exemple, le mot "trouvez" accepte le lemme "trouver".

# %%
from nltk.stem import WordNetLemmatizer
lem=WordNetLemmatizer()

def lem_word(sentence): 
    words = sentence.split() 
    words =\
        [lem.lemmatize(word) for word in words ] #SOLUTION
    return ' '.join(words)

# %% [markdown]
# Parfois, les mots dont la longueur est inférieure ou égal à deux caractères n'apportent pas d'informations importantes et c'est mieux de les supprimer.
#
# Écrivez la fonction qui retire les mots ayant moins que deux caractères :

# %%
# Retrait des mots ayant moins que deux caractères
def remove_small(sentence):

    words = sentence.split() 
    words =\
        [word for word in words if len(word)>=3] #SOLUTION
    return ' '.join(words)

# %% [markdown]
# Ecrivons la fonction _clean_text_ qui joint tous ces différents fonctions pour nettoyer proprement les tweets.

# %%
 def clean_text(data):
    data['text'] = data['text'].apply(lambda x : remove_url(x))
    data['text'] = data['text'].apply(lambda x : remove_html(x))
    #data['text'] = data['text'].apply(lambda x : stem_words(x))
    data['text'] = data['text'].apply(lambda x : remove_ponctuation(x))
    data['text'] = data['text'].apply(lambda x : remove_stopwords(x))
    data['text'] = data['text'].apply(lambda x : remove_emoji(x))
    data['text'] = data['text'].apply(lambda x : remove_small(x))
    data['text'] = data['text'].apply(lambda x : lem_word(x))
    data['text'] = data['text'].apply(lambda x : nlp_pipeline(x))
    return data

# %% [markdown]
# Maintenant que le pipeline de prétraitement est prêt, appliquons-le aux deux types de données : l'ensemble de données d'entraînement et l'ensemble de données de test.

# %%
# Appliquer le nettoyage aux deux types des données: l'ensemble des données d'apprentissage et l'ensemble des données test
D = clean_text(train_data)
test_data_c=clean_text(test_data)

# Données avant nettoyage
train_data.head()
# Out:
#                                                 text  target
# 0      our deeds reason earthquake may allah forgive       1
# 1                forest fire near ronge sask. canada       1
# 2  all resident asked shelter place notified offi...       1
# 3   people receive wildfires evacuation order cal...       1
# 4  just got sent photo ruby alaska smoke wildfire...       1

# %% [markdown]
# Vérifiez s'il y a des tweets vides après le nettoyage puis éliminez-les.

# %%
print(\ 
      D.loc[D.text==""].shape[0])   #SOLUTION

# Eliminer les tweets vides s'il y en a.
D =\
    D.loc[D.text!= ""] #SOLUTION

print(D.shape)

D.text.head()
# Out:
# 0
# (7531, 2)
# 0        our deeds reason earthquake may allah forgive
# 1                  forest fire near ronge sask. canada
# 2    all resident asked shelter place notified offi...
# 3     people receive wildfires evacuation order cal...
# 4    just got sent photo ruby alaska smoke wildfire...
# Name: text, dtype: object

# %% [markdown]
# Nous pouvons identifier visuellement certains termes qui sont le plus souvent associés à notre sujet d'intérêt, qui dans ce cas est "catastrophe". Cela peut se faire à l'aide d'un nuage de mots :

# %%
# Il faut installer wordCloud
#!pip install wordcloud

from wordcloud import WordCloud

# Céer Wordcloud à partir des tweets
# https://www.geeksforgeeks.org/generating-word-cloud-python/
D.text
all_words = ' '.join([text for text in D.text])
wordcloud =\
    WordCloud(width=800, height=500, random_state=21, max_font_size=110).generate(all_words) #SOLUTION

plt.figure(figsize=(10, 7))
plt.imshow(wordcloud, interpolation="bilinear")
plt.axis('off')
plt.show()

# %% [markdown]
# Nous allons partager l'ensemble des données d'apprentissage des données de tweets en deux parties: apprentissage-validation.
# Pour rappel, à quoi servira chaque partie&nbsp;?
#
# <blockquote>
# <strong style="text-decoration:underline;display:block">Solution</strong>
#
# La partie apprentissage servira à entraÎner le réseau de neurones quant à la partie validation, elle sert à mesurer la performance de l'architecture. En général, la partie apprentissage comprend 75% du total des données et la partie validation comprend 25% de l'ensemble des données d'apprentissage.
# </blockquote>

# %%
# Partition appretissage-test
from sklearn.model_selection import train_test_split 
dtrain, dtest =\
    train_test_split(D,train_size=0.75,stratify=D.target,random_state=0) #SOLUTION

# Vérification du découpage
print(dtrain.shape)
print(dtest.shape)
# Out:
# (5648, 2)
# (1883, 2)

# %% [markdown]
# La sortie précise qu'on a 7530 tweets au complet dont 5648 appartenant à l'entraÎnement et 1883 à la validation. Maintenant que le jeu de données est prêt, il faut passer à constituer le dictionnaire issu de l'échantillon d'apprentissage.
#
# ### Tokénisation ou segmentation
#
# Un modèle ne comprendra pas ce qu'il faut faire avec une chaîne représentant une phrase. Au lieu de cela, elle doit être convertie en un tableau de chiffres représentant les mots de la phrase. Un Tokeniser devrait nous être utile. Quel est son fonctionnement ?
#
# <blockquote>
# <strong style="text-decoration:underline;display:block">Solution</strong>
#
# Un Tokenizer simple attribue un indice numérique à chaque mot unique de la phrase afin que le modèle puisse le traiter comme une valeur catégorielle. Il transforme les mots de la phrase en entités puis convertir les entités en nombres. Fondamentalement, c'est ce que fait le Tokenizer à ce stade du prétraitement. Il convertira tous les mots du texte en séquence de nombres. Il attribuait des nombres en fonction de l'ordre alphabétique.
#
#
# Pour y parvenir, nous allons définir deux fonctions:
# <ul>
#     <li>La première définit le Tokenizer en prenant toutes les phrases des trois ensembles de données, apprentissage, validation et test, et en attribuant un numéro d'indice à chaque mot présent dans les phrases. Les trois ensembles de données sont utilisés ici pour s'assurer que le vocabulaire du Tokenizer inclut tous les mots présents dans les tweets. Une petite analyse à la fin de ce Workshop, sera consacré à montrer combien de mots sont dans un des ensembles de données et pas dans les autres.</li>
#     <li>La deuxième fonction utilise le Tokenizer pour encoder toutes les phrases dans un tableau de numéros d'indice représentant la phrase.</li>
# </ul>
# </blockquote>
#
# Pour en savoir plus sur les différents modules du Tokenizer, consultez la [documentation](https://www.tensorflow.org/api_docs/python/tf/keras/preprocessing/text/Tokenizer/).

# %%
# Tokenisation avec Keras
from keras. preprocessing.text import Tokenizer

def define_tokenizer(train_sentences, val_sentences, test_sentences):
    sentences = pd.concat([train_sentences, val_sentences, test_sentences])
    tokenizer = tf.keras.preprocessing.text.Tokenizer()
    
    ## Création du dictionnaire à partir des documents de l'échantillon
    tokenizer.fit_on_texts(sentences)
    
    return tokenizer
  
def encode(sentences, tokenizer):
    encoded_sentences = tokenizer.texts_to_sequences(sentences)
    encoded_sentences =\
        tf.keras.preprocessing.sequence.pad_sequences(encoded_sentences, padding='post') #SOLUTION 
    
    return encoded_sentences

# %% [markdown]
# Quel est le rôle de l'option <code class="cm-s-ipython language-python"><span class="cm-variable">padding</span><span class="cm-operator">=</span><span class="cm-variable">post</span></code>) dans la deuxieme fonction?
#
# <blockquote>
# <strong style="text-decoration:underline;display:block">Solution</strong>
#
# Avec ce paramètre, la deuxième fonction remplit aussi les phrases de zéros afin qu'elles aient toutes la même taille que la phrase la plus longue de l'ensemble de données. Notons que le Tokenizer réserve l'indice 0 à cette fin (avec l'option <code class="cm-s-ipython language-python"><span class="cm-variable">padding</span><span class="cm-operator">=</span><span class="cm-string">'post'</span></code>)
# </blockquote>
#
# Appliquez la tokenisation aux 3 types de données, utilisez le Tokenizer et encodez les phrases dans un tableau de numéros d'indice représentant la phrase. Nommez-les respectivement: `encoded_sentences`, `val_encoded_sentences` et `encoded_test_sentences` :

# %%
tokenizer =\
    define_tokenizer(dtrain['text'], dtest['text'], test_data_c['text']) #SOLUTION
 
encoded_sentences = encode(dtrain['text'], tokenizer)
val_encoded_sentences =\
    encode(dtest['text'], tokenizer) #SOLUTION
encoded_test_sentences =\
    encode(test_data_c['text'], tokenizer) #SOLUTION

# Nombre du documents traités
print(tokenizer.document_count)
# Out:
# 10794

# %% [markdown]
# Le Tokeniseur fournit quelques informations intéressantes sur les phrases qu'il encode. Pour obtenir le numéro d'indice assigné à un mot, avec `word_index`, on peut chercher le mot dans l'indice des mots du Tokeniseur (qui est juste un dictionnaire Python avec les mots comme clés et les numéros d'index comme valeurs), et regarder aussi quelques autres informations.

# %%
print(tokenizer.word_index['disaster'])
print(tokenizer.word_index['target'])

# Taille du vocabulaire
print(len(tokenizer.word_index))

# Liste des mots et leurs fréquences
print(list(tokenizer.word_counts.items())[:10])

#Liste triée dans l'ordre de la fréquence décroissante
print(sorted(list(tokenizer.word_counts.items()),key=lambda x: -x[1])[:20])
# Out:
# 15
# 1076
# 20000
# [('lava', 52), ('you', 235), ('former', 23), ('executives', 3), ('prosecuted', 8), ('fukushima', 32), ('nuclear', 141), ('disaster', 215), ('the', 978), ('story', 70)]
# [('the', 978), ('like', 487), ('fire', 467), ('get', 373), ('im', 350), ('new', 328), ('via', 312), ('one', 286), ('news', 285), ('people', 279), ('video', 236), ('you', 235), ('emergency', 225), ('this', 223), ('disaster', 215), ('would', 207), ('police', 198), ('body', 196), ('time', 185), ('day', 181)]

# %% [markdown]
# Le terme important le plus fréquenté est <em>like</em>, il apparaît 487 fois dans un ou plusieurs documents. Le terme <em>fire</em> apparaît 484 fois, <em>emergency</em> apparaît 226 fois, <em>disaster</em> apparaît 220 fois.
#
# Bien, passons maintenant à la matrice documentaire (text to matrix).

# %% [markdown]
# ###  Word Embedding: convertir un document en une matrice de nombres
#
# Après avoir prétraité les données du texte et crée le dictionnaire, on doit faire du <em>Word Embedding</em>.
#
# Pourquoi devons-nous utiliser le Word Embedding en NLP ?
#
# <blockquote>
# <strong style="text-decoration:underline;display:block">Solution</strong>
#
# Dans les modèles NLP, nous traitons des textes qui sont compréhensibles par l'homme. Pour que la machine puisse les comprendre il faut les transformer en chiffres. le Word Embedding  ou <em>incoporation ou prolongement des mots</em> permet d'inclure implicitement des informations externes du monde extérieur à vos modèles NLP. Chaque mot utilisé dans une langue peut être représenté par un un vecteur de mots unique qui est simplement une liste de chiffres pour chaque mot. L'incorporation capture la "signification" du mot. Les mots similaires se retrouvent avec des valeurs d'intégration similaires. Pour un bon modèle, les embeddings ont généralement une longueur comprise entre 50 et 500. Une intégration dimensionnelle plus élevée peut capturer des relations fines entre les mots, mais nécessite plus de données pour apprendre. Ainsi, le Word Embedding, est capable en réduisant la dimension de capturer le contexte, la similarité sémantique et syntaxique (genre, synonymes, …) d’un mot. L'ensemble de vecteurs de mots pour un vocabulaire peut capturer le sens des mots, la relation entre les mots et le contexte des différents mots tels qu'ils sont utilisés naturellement.
# </blockquote>
#
# Il existe différentes techniques qui dépendent du cas d'utilisation du modèle et de l'ensemble de données. Nous citons One Hot Encoding, TF-IDF, Word2Vec et FastText (https://towardsdatascience.com/word-embedding-techniques-word2vec-and-tf-idf-explained-c5d02e34d08). Nous avons choisi [GloVe](https://datamahadev.com/nlp-stanfords-glove-for-word-embedding/) pour cette tâche. GloVe (<em>Global Vectors for Word Representation</em>), a été créé par l'Université de Stanford. Comme son nom l'indique, il permet de mieux préserver les contextes globaux car il crée une matrice de co-occurrence globale en estimant la probabilité qu'un mot donné soit co-occurrent avec d'autres mots. Il gère donc les tâches nécessitant un raisonnement analogique sur les mots et les tâches nécessitant la capture de la similarité des mots. Il possède des vecteurs denses prédéfinis pour environ 6 milliards de mots de la littérature anglaise, ainsi que de nombreux autres caractères d'usage général comme la virgule, les accolades et le point-virgule.
#
# Après avoir prétraité les données du texte et crée le dictionnaire. nous devons parcourir le fichier de Glove d'une dimension spécifique et comparer chaque mot avec tous les mots du dictionnaire, en cas de correspondance, copier le vecteur équivalent du Glove et le coller dans `embedding_matrix` à l'index correspondant. La première chose à faire est donc de charger l'incorporation.
#
# Tout d'abord, nous allons télécharger et décompresser les embeddings GloVe. Plus précisément, nous allons récupérer la [représentation pré-entraînée Glove](http://nlp.stanford.edu/data/glove.6B.zip). Je vous conseille de prendre le temps d'explorer ces données !
#
# <blockquote class="comment">
# <strong style="text-decoration:underline;display:block">Explications</strong>
# L'entraînement est effectué sur des statistiques globales agrégées de co-occurrence mot-mot provenant d'un corpus, et les représentations résultantes présentent des sous-structures linéaires intéressantes de l'espace vectoriel des mots. Le résultat est un modèle de régression log-bilinéaire global qui combine les avantages des deux principaux modèles de la littérature : la factorisation matricielle globale et la fenêtre contextuelle locale.
# </blockquote>

# %%
from zipfile import ZipFile

zf = ZipFile('glove.6B.zip', 'r')
zf.extractall('glove.6B')
zf.close()

# %% [markdown]
# Maintenant, calculons un index qui met en correspondance les mots avec les incorporations connues, en analysant la base de données des incorporations pré-entraînées :

# %%
embedding_dict = {}

f=open(os.path.join('glove.6B', 'glove.6B.100d.txt'),'r',encoding='utf-8')
for line in f:
        values = line.split()
        word = values[0]
        vectors = np.asarray(values[1:],'float32')
        # Transformer chaque mot en un vecteur de dimensions 100.
        embedding_dict[word] = vectors #SOLUTION
        
f.close()


# Vérification  du nombre des termes
print('Found %s word vectors.' % len(embedding_dict))
# Out:
# Found 400000 word vectors.

# %% [markdown]
# Testons la présence de certains termes, et leur similarité :

# %%
# Coordonnées des termes good et nice
print(embedding_dict['good'])
print(embedding_dict['nice'])

# Similarité entre good et nice: si la valeur est proche de 1 alors il y a une forte similarité
import scipy 

from scipy.spatial import distance
print(1.0-scipy.spatial.distance.cosine(embedding_dict['good'],embedding_dict['nice']))
# Out:
# [-0.030769   0.11993    0.53909   -0.43696   -0.73937   -0.15345
#   0.081126  -0.38559   -0.68797   -0.41632   -0.13183   -0.24922
#   0.441      0.085919   0.20871   -0.063582   0.062228  -0.051234
#  -0.13398    1.1418     0.036526   0.49029   -0.24567   -0.412
#   0.12349    0.41336   -0.48397   -0.54243   -0.27787   -0.26015
#  -0.38485    0.78656    0.1023    -0.20712    0.40751    0.32026
#  -0.51052    0.48362   -0.0099498 -0.38685    0.034975  -0.167
#   0.4237    -0.54164   -0.30323   -0.36983    0.082836  -0.52538
#  -0.064531  -1.398     -0.14873   -0.35327   -0.1118     1.0912
#   0.095864  -2.8129     0.45238    0.46213    1.6012    -0.20837
#  -0.27377    0.71197   -1.0754    -0.046974   0.67479   -0.065839
#   0.75824    0.39405    0.15507   -0.64719    0.32796   -0.031748
#   0.52899   -0.43886    0.67405    0.42136   -0.11981   -0.21777
#  -0.29756   -0.1351     0.59898    0.46529   -0.58258   -0.02323
#  -1.5442     0.01901   -0.015877   0.024499  -0.58017   -0.67659
#  -0.040379  -0.44043    0.083292   0.20035   -0.75499    0.16918
#  -0.26573   -0.52878    0.17584    1.065    ]
# [-0.18554    0.047152   0.34867   -0.23114   -0.26083    0.63108
#   0.55687    0.61622   -0.15437   -0.38381    0.12445   -0.26999
#  -0.29196    0.1125     0.36035    0.70689   -0.33891   -0.2695
#   0.17481    0.97048    0.23014    0.63168   -0.24543   -0.7289
#   0.32517   -0.21118   -0.80354   -0.59863   -0.10182   -0.87826
#  -0.80162    0.20999    0.64598   -0.38239    0.64512    0.73046
#  -0.19881    0.35717    0.19135   -0.43686    0.75956   -0.66431
#   0.34509   -1.0383    -0.50491    0.19976   -0.041208   0.16952
#   0.17821   -0.84249    0.21992   -0.16474   -0.24669    0.34117
#  -0.59713   -2.3434     0.31484    0.69668    0.53368   -0.62857
#  -0.197      0.52241   -1.5903    -0.16475    0.62553   -0.094116
#   0.0070705  0.22617   -0.45698   -0.53268    0.11573   -0.19052
#   0.28086   -0.5591     0.35291    0.42552    0.47334   -0.41046
#   0.47275    0.22753   -0.097073  -0.11809   -0.25613   -0.10689
#  -1.2788    -0.085504   0.20205    0.23338   -0.52939   -0.49492
#   0.15289   -0.31324    0.41248   -0.10425   -0.65246    0.48348
#  -0.54844    0.095473  -0.1142     0.32743  ]
# 0.7312452793121338

# %% [markdown]
# Nous allons utiliser la fonction ci-dessous pour s'assurer que le terme de notre dictionnaire recherché soit présent dans la représentation pré-entrainée de GloVe. A ce stade, nous pouvons utiliser notre dictionnaire `embedding_dict` et notre `word_dict` pour calculer notre matrice d'incorporation :

# %%
# Matrice initiale emmbedding pour notre jeu de données
hit=0
misses=[]

# Nombre de token ( numpy est à base zéro)
num_words =\
    len(tokenizer.word_index) + 1 #SOLUTION

# Dimension de représentation =100 selon Glove choisi
embedding_matrix = np.zeros((num_words, 100))

# On remplit la matrice avec les coordonnées issues de la représentation pré-entrainée
# Pourvu que le terme de notre dictionnaire recherché soit présent dans la représentation pré-entrainée de GloVe
for word, i in tokenizer.word_index.items():
    if i > num_words:
        continue
    
    emb_vec = embedding_dict.get(word)
    
    if emb_vec is not None:
        embedding_matrix[i] = emb_vec
        hit = hit+1
    else:
        misses.append(word)
        
# Affichage de controle: le nombre de termes trouvés et non trouvés dans la représentation pré-entrainée de GloVe.

print(\
      'termes du dict trouvés={0}, non trouvés={1}'.format(hit, len(misses))) #SOLUTION
# Out:
# termes du dict trouvés=13991, non trouvés=6009

# %% [markdown]
# On trouve 6009 termes non référencés c.à.d 6009 termes présents dans les tweets mais pas dans GloVe. Les lignes correspondantes sont transformées en zéro dans notre matrice. C'est une perte d'information car elles ne sont jamais entraînées.

# %%
print(misses[:10])
# Out:
# ['yearold', 'typhoondevastated', 'bestnaijamade', 'nowplaying', 'disea', 'reddits', 'subreddits', 'prebreak', 'gbbo', 'donªt']

# %% [markdown]
# On peut vérifier que ces termes ne sont pas présents dans le document Glove choisi, vu qu'il y a des termes qui ont été mal transformé dans la phase du prétraitement.

# %% [markdown]
# ### Préparation du pipeline
#
# Avec les phrases encodées, ces phrases peuvent maintenant être préparées pour être introduites dans le modèle. TensorFlow fournit une API pour formater les données dans son propre format. Bien que les données puissent être insérées dans un format plus courant (comme les tableaux numpy), TensorFlow semble préférer son propre format et fournit quelques fonctionnalités pratiques comme incitations.
#
# Dans un premier temps, nous allons donc convertir les phrases et les étiquettes codées en tenseurs.

# %%
tf_data = tf.data.Dataset.from_tensor_slices((encoded_sentences, dtrain['target'].values))

# %% [markdown]
# Maintenant que les données sont au format TensorFlow, quelques méthodes pratiques peuvent être ajoutées pour améliorer la l'entrainement. Il s'agit notamment de mélanger les données à chaque étape de l'apprentissage, de traiter le prochain lot de données pour l'apprentissage pendant que le lot de données actuel est en cours d'apprentissage et de définir chaque lot comme un lot padded.

# %%
def pipeline(tf_data, buffer_size=100, batch_size=32):
    tf_data = tf_data.shuffle(buffer_size)    
    tf_data = tf_data.prefetch(tf.data.experimental.AUTOTUNE)
   
    tf_data =\
        tf_data.padded_batch(batch_size, padded_shapes=([None],[])) #SOLUTION
       
    return tf_data

tf_data = pipeline(tf_data, buffer_size=1000, batch_size=32)

print(tf_data)
# Out:
# <PaddedBatchDataset element_spec=(TensorSpec(shape=(None, None), dtype=tf.int32, name=None), TensorSpec(shape=(None,), dtype=tf.int64, name=None))>

# %% [markdown]
# Définissons un pipeline similaire pour l'ensemble de données test. La différence est l'absence de brassage pour accélérer la validation.

# %%
tf_val_data =\
    tf.data.Dataset.from_tensor_slices((val_encoded_sentences, dtest['target'].values)) #SOLUTION

def val_pipeline(tf_data, batch_size=1):        
    tf_data = tf_data.prefetch(tf.data.experimental.AUTOTUNE)
    tf_data =\
        tf_data.padded_batch(batch_size, padded_shapes=([None],[])) #SOLUTION
    
    return tf_data

tf_val_data = val_pipeline(tf_val_data, batch_size=len(dtest))

print(tf_val_data)
# Out:
# <PaddedBatchDataset element_spec=(TensorSpec(shape=(None, None), dtype=tf.int32, name=None), TensorSpec(shape=(None,), dtype=tf.int64, name=None))>

# %% [markdown]
# ## Entraînement du modèle
#
# Nous sommes maintenant prêts à définir et à entraîner le modèle. Tout d'abord, nous allons définir le modèle !!!
#
# ![graphRNN1.png](attachment:graphRNN1.png)
#
# Trois couches sont à définir: une couche d'embedding, une couche de RNN et une couche dense.
# Expliquez le fonctionnement de chaque couche.
#
# <blockquote>
# <strong style="text-decoration:underline;display:block">Solution</strong>
#
# <ul>
#     <li> <strong>Couche Emebbedding :</strong> Pour permettre au modèle de comprendre le sens d'un mot, il a besoin d'une incorporation de mots. Cet encastrement crée un certain nombre de caractéristiques génériques pour chaque mot, qui peuvent représenter les mots en classe positif ou négatif. Cela permet également au modèle d'identifier les relations entre les mots. La <a href="https://www.tensorflow.org/tutorials/text/word_embeddings">documentation de Tensorflows</a> contient une bonne explication de cette couche.</li>
#     <li> <strong>Couche RNN:</strong> Une couche de type RNN. Consultez le lien suivant pour une explication complète de la théorie. TensorFlow offre les trois principales couches RNN : RNN simple, GRU et LSTM.</li>
#     <li> <strong>Couche dense:</strong> Cette couche finale prend la sortie du RNN et applique une classe à la phrase, c'est-à-dire un 1 si la phrase rapporte un vrai désastre ou un 0 si non.
#     </li>
# </ul>
# <blockquote>

# %%
# Couche Embedding
embedding = tf.keras.layers.Embedding(
    len(tokenizer.word_index)+1,
    100, 
    embeddings_initializer = tf.keras.initializers.Constant(embedding_matrix),
    trainable=False # cette couche embedding est fixée, il ne faut pas
                    # qu'elle soit rentrée dans la couche d'entrainement
)

# %% [markdown]
# ### RNN: Réseaux de neurones réccurents simples
#
# Les réseaux de neurones récurrents simples ne sont pas adaptés aux données de langages naturels, ils sont plus utilisés pour les données séquentielles.
# Pour la couche RNN, les RNN simples ne donnent pas une bonne performance; en effet, l'un de leurs principaux problèmes est la disparition des gradients ou en anglais _Vanishing gradient_. Les RNNs peuvent être assez longs, et peuvent avoir du mal à rétropropager les gradients jusqu'à la première couche du réseau. Lorsque cela se produit, le réseau ne peut pas apprendre les relations entre des tokens éloignés.

# %% [markdown]
# À votre avis, quelle est la conséquence du Vanishing problem ?
#
# <blockquote>
# <strong style="text-decoration:underline;display:block">Solution</strong>
#
# Les réseaux de neurones récurrents souffrent d'une mémoire à court terme. Si une séquence est suffisamment longue, ils auront du mal à transférer les informations des étapes précédentes aux étapes suivantes. Ainsi, si vous essayez de traiter un paragraphe de texte pour faire des prédictions, les RNN risquent d'omettre des informations importantes dès le début.
#
# Comme pour tous les Réseaux Neuronaux, la mise à jour des valeurs des paramètres d'un RNN se fait via l'algorithme d'apprentissage <em>BackPropagation</em> à partir du gradient de l'erreur. Pendant la rétropropagation, les réseaux neuronaux récurrents souffrent du problème du gradient évanescent, appelé en anglais <em>Vanishing problem</em>.
#
# Toutes les couches d'un RNN simples sont identiques (il s'agit en fait d'un Fully Connnected Layer à <em>BPTT</em> couches, avec <em>BPTT</em> (<em>BackPropagation Through Time</em>) le nombre de tokens de la séquence dont le modèle a gardé la mémoire. Par conséquent, chaque paramètre d'un RNN est mis à jour <em>BPTT</em> fois lors de la backpropagation du gradient de l'erreur, c'est-à-dire qu'il est multiplié <em>BPTT</em> fois par un nombre inférieur à 1, comme le Learning Rate et le gradient de l'erreur. Ce problème du gradient se produit lorsque le gradient se réduit  dans le temps au fur et à mesure de la rétropropagation. Il devient extrêmement petit et finit par conséquent par converger vers zéro: il y a alors perte de gradient et il n'est plus possible de mettre à jour les paramètres du RNN. C'est le <em>Vanishing Gradient Problem</em>.
# </blockquote>

# %% [markdown]
# Si vous en avez envie, vous pouvez essayer le fonctionnement de RNN simples et voir ce que ça peut donner dans notre cas. Ne le faites pas pendant le Workshop, vous perdrez du temps d'apprentissage pour rien.
# <blockquote class="comment">
# <strong style="text-decoration:underline;display:block">Explications</strong>
# Voici le code si les élèves veulent tester. Ils obtiendront des résultats très médiocres.
#
#
# <pre><code class="cm-s-ipython language-python"><span class="cm-variable">model0</span> <span class="cm-operator">=</span> <span class="cm-variable">tf</span>.<span class="cm-property">keras</span>.<span class="cm-property">Sequential</span>([
#     <span class="cm-variable">enbedding</span>,
#     <span class="cm-variable">tf</span>.<span class="cm-property">keras</span>.<span class="cm-property">layers</span>.<span class="cm-property">Bidirectional</span>(<span class="cm-variable">tf</span>.<span class="cm-property">keras</span>.<span class="cm-property">layers</span>.<span class="cm-property">SimpleRNN</span>(<span class="cm-number">64</span>)),
#     <span class="cm-variable">tf</span>.<span class="cm-property">keras</span>.<span class="cm-property">layers</span>.<span class="cm-property">Dense</span>(<span class="cm-number">1</span>, <span class="cm-variable">activation</span><span class="cm-operator">=</span><span class="cm-string">'sigmoid'</span>)
# ])</code></pre>
# </blockquote>

# %% [markdown]
# Comment éviter ce problème ?
#
# <blockquote>
# <strong style="text-decoration:underline;display:block">Solution</strong>
#
# Dans le cas du Vanishing problem, il faut soit diminuer le BPTT (ce qui est dommage), soit utiliser des architectures de RNN un peu plus complexes avec une mémoire à long terme.
# </blockquote>
#
# Parmi les trois architectures de RNN, quelles sont celles qui permettent de le faire ?
#
# <blockquote>
# <strong style="text-decoration:underline;display:block">Solution</strong>
#
# <ul>
#     <li>Les GRU: Gated Recurrent Units</li>
#     <li>Les LSTM: Long short Term  Memory</li>
# </ul>
#
# Ces deux architectures introduisent une gestion explicite de l'état en utilisant des portes.  Elles permettent de garder à chaque cellule une partie du vecteur d'état précédent (et donc du vecteur d'état initial).
# </blockquote>
#
# Nous allons appliquer et comparer ces types de réseaux de neurones récurrents.

# %% [markdown]
# ### GRU: Gated Recurrent Units
#
# Nous allons tout d'abord essayer de comprendre l'architecture du réseaux de neurones de type GRU ( Gated Recurrent Unit).
# Ces réseaux de neurones sont formés de deux portes :
#
# ![image-2.png](attachment:image-2.png)
#
# Chaque "porte" correspond à un petit réseau neuronal avec sigmoïde comme fonction d'activation dont le but est de ramener les valeurs des vecteurs en entrée de la porte entre 0 et 1.
#
# Comment s'appellent ces deux portes (gates en anglais) nommées A et B dans la figure ? Quelle est le fonctionnement de chacune ?
#
# <blockquote>
# <strong style="text-decoration:underline;display:block">Solution</strong>
#
# <ul>
#     <li>La porte A est appelée <em>Reset gate</em>, ou porte de réinitialisation, elle est utilisée à partir du modèle pour décider de la quantité d'informations passées à ignorer ; en fait, elle décide si l'état précédent de la cellule est important ou non.</li>
#     <li>La porte B est appelée <em>Update gate</em>, ou porte de mise à jour, elle est chargée de déterminer la quantités d'informations précédentes qui doivent être transmises à l'état suivant. Le modèle peut décider de copier toutes les informations du passé et éliminer le risque de Vanishing Gradient.</li>
# </ul>
# </blockquote>
#
# Vous trouverez une description plus détaillée du GRU dans [Illustrated Guide to LSTM’s and GRU’s: A step by step explanation](https://towardsdatascience.com/illustrated-guide-to-lstms-and-gru-s-a-step-by-step-explanation-44e9eb85bf21).
#
# Créons donc le modèle 1 avec le type GRU, constitué d'une couche cachée, de 128 neurones, et un droupout de 0.2 :

# %%
# Création de l'architecture du modèle 1
model1 = tf.keras.Sequential([
    embedding,
   tf.keras.layers.SpatialDropout1D(0.2),
    # GRU avec 128 neurones et un dropout=0.2
    tf.keras.layers.GRU(128,dropout=0.2) #SOLUTION
    ,tf.keras.layers.Dense(1, activation='sigmoid')
])

model1.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding (Embedding)       (None, None, 100)         2000100
#
#  spatial_dropout1d_1 (Spatia  (None, None, 100)        0
#  lDropout1D)
#
#  gru_1 (GRU)                 (None, 128)               88320
#
#  dense_1 (Dense)             (None, 1)                 129
#
# =================================================================
# Total params: 2,088,549
# Trainable params: 88,449
# Non-trainable params: 2,000,100
# _________________________________________________________________

# %% [markdown]
# Puis nous compilons le modèle en définissant la fonction d'apprentissage (avec un Adam de 0.01) et la fonction de perte (ici, loss binary crossentropy). Nous avons également ajouté un paramètre de métrique pour que la précision du modèle soit imprimée par époque.

# %%
model1.compile(
    loss=\
        tf.keras.losses.BinaryCrossentropy(from_logits=True) #SOLUTION
    , optimizer=tf.keras.optimizers.Adam(0.01),
    metrics=['accuracy']
)

# %% [markdown]
# Finalement, nous commençons l'entraînement du modèle sur la partie train, avec 50 époques :

# %%
history1 = model1.fit(
    tf_data, 
    validation_data = tf_val_data,
    epochs = 50
  )
# Out:
# Epoch 1/50
# C:\tools\Anaconda3\lib\site-packages\keras\backend.py:5676: UserWarning: "`binary_crossentropy` received `from_logits=True`, but the `output` argument was produced by a Sigmoid activation and thus does not represent logits. Was this intended?
#   output, from_logits = _get_logits(
# 177/177 [==============================] - 4s 12ms/step - loss: 0.5420 - accuracy: 0.7440 - val_loss: 0.4474 - val_accuracy: 0.8072
# Epoch 2/50
# 177/177 [==============================] - 2s 10ms/step - loss: 0.4642 - accuracy: 0.7918 - val_loss: 0.4401 - val_accuracy: 0.8104
# Epoch 3/50
# 177/177 [==============================] - 2s 11ms/step - loss: 0.4357 - accuracy: 0.8051 - val_loss: 0.4546 - val_accuracy: 0.7971
# Epoch 4/50
# 177/177 [==============================] - 2s 11ms/step - loss: 0.4268 - accuracy: 0.8077 - val_loss: 0.4374 - val_accuracy: 0.8062
# Epoch 5/50
# 177/177 [==============================] - 2s 11ms/step - loss: 0.4057 - accuracy: 0.8215 - val_loss: 0.4391 - val_accuracy: 0.8024
# Epoch 6/50
# 177/177 [==============================] - 2s 11ms/step - loss: 0.4013 - accuracy: 0.8251 - val_loss: 0.4667 - val_accuracy: 0.7945
# Epoch 7/50
# 177/177 [==============================] - 2s 11ms/step - loss: 0.3965 - accuracy: 0.8295 - val_loss: 0.4581 - val_accuracy: 0.7961
# Epoch 8/50
# 177/177 [==============================] - 2s 11ms/step - loss: 0.4020 - accuracy: 0.8237 - val_loss: 0.5061 - val_accuracy: 0.7594
# Epoch 9/50
# 177/177 [==============================] - 2s 12ms/step - loss: 0.4133 - accuracy: 0.8175 - val_loss: 0.4863 - val_accuracy: 0.7908
# Epoch 10/50
# 177/177 [==============================] - 2s 11ms/step - loss: 0.4145 - accuracy: 0.8205 - val_loss: 0.4877 - val_accuracy: 0.7966
# Epoch 11/50
# 177/177 [==============================] - 2s 11ms/step - loss: 0.4291 - accuracy: 0.8081 - val_loss: 0.4676 - val_accuracy: 0.7993
# Epoch 12/50
# 177/177 [==============================] - 2s 11ms/step - loss: 0.4204 - accuracy: 0.8157 - val_loss: 0.4545 - val_accuracy: 0.8014
# Epoch 13/50
# 177/177 [==============================] - 2s 11ms/step - loss: 0.4087 - accuracy: 0.8192 - val_loss: 0.4933 - val_accuracy: 0.7902
# Epoch 14/50
# 177/177 [==============================] - 2s 11ms/step - loss: 0.4160 - accuracy: 0.8139 - val_loss: 0.4582 - val_accuracy: 0.7913
# Epoch 15/50
# 177/177 [==============================] - 2s 11ms/step - loss: 0.4145 - accuracy: 0.8157 - val_loss: 0.4600 - val_accuracy: 0.7939
# Epoch 16/50
# 177/177 [==============================] - 2s 11ms/step - loss: 0.4385 - accuracy: 0.8054 - val_loss: 0.4703 - val_accuracy: 0.7939
# Epoch 17/50
# 177/177 [==============================] - 2s 11ms/step - loss: 0.4462 - accuracy: 0.7964 - val_loss: 0.4606 - val_accuracy: 0.7924
# Epoch 18/50
# 177/177 [==============================] - 2s 11ms/step - loss: 0.4431 - accuracy: 0.7992 - val_loss: 0.4678 - val_accuracy: 0.7982
# Epoch 19/50
# 177/177 [==============================] - 2s 11ms/step - loss: 0.4614 - accuracy: 0.7882 - val_loss: 0.4765 - val_accuracy: 0.7881
# Epoch 20/50
# 177/177 [==============================] - 2s 11ms/step - loss: 0.4634 - accuracy: 0.7897 - val_loss: 0.4835 - val_accuracy: 0.7844
# Epoch 21/50
# 177/177 [==============================] - 2s 11ms/step - loss: 0.4516 - accuracy: 0.7971 - val_loss: 0.4898 - val_accuracy: 0.7748
# Epoch 22/50
# 177/177 [==============================] - 2s 11ms/step - loss: 0.4935 - accuracy: 0.7718 - val_loss: 0.5081 - val_accuracy: 0.7594
# Epoch 23/50
# 177/177 [==============================] - 2s 11ms/step - loss: 0.5189 - accuracy: 0.7535 - val_loss: 0.5162 - val_accuracy: 0.7515
# Epoch 24/50
# 177/177 [==============================] - 2s 11ms/step - loss: 0.5224 - accuracy: 0.7518 - val_loss: 0.5239 - val_accuracy: 0.7557
# Epoch 25/50
# 177/177 [==============================] - 2s 11ms/step - loss: 0.5328 - accuracy: 0.7459 - val_loss: 0.5350 - val_accuracy: 0.7483
# Epoch 26/50
# 177/177 [==============================] - 2s 11ms/step - loss: 0.5271 - accuracy: 0.7489 - val_loss: 0.4913 - val_accuracy: 0.7711
# Epoch 27/50
# 177/177 [==============================] - 2s 11ms/step - loss: 0.5112 - accuracy: 0.7587 - val_loss: 0.4985 - val_accuracy: 0.7658
# Epoch 28/50
# 177/177 [==============================] - 2s 11ms/step - loss: 0.5113 - accuracy: 0.7566 - val_loss: 0.5239 - val_accuracy: 0.7568
# Epoch 29/50
# 177/177 [==============================] - 2s 11ms/step - loss: 0.5151 - accuracy: 0.7557 - val_loss: 0.5131 - val_accuracy: 0.7663
# Epoch 30/50
# 177/177 [==============================] - 2s 11ms/step - loss: 0.5060 - accuracy: 0.7594 - val_loss: 0.4965 - val_accuracy: 0.7637
# Epoch 31/50
# 177/177 [==============================] - 2s 11ms/step - loss: 0.5013 - accuracy: 0.7686 - val_loss: 0.5026 - val_accuracy: 0.7658
# Epoch 32/50
# 177/177 [==============================] - 2s 11ms/step - loss: 0.5013 - accuracy: 0.7670 - val_loss: 0.4819 - val_accuracy: 0.7738
# Epoch 33/50
# 177/177 [==============================] - 2s 11ms/step - loss: 0.5042 - accuracy: 0.7626 - val_loss: 0.4774 - val_accuracy: 0.7828
# Epoch 34/50
# 177/177 [==============================] - 2s 11ms/step - loss: 0.5048 - accuracy: 0.7587 - val_loss: 0.4990 - val_accuracy: 0.7631
# Epoch 35/50
# 177/177 [==============================] - 2s 11ms/step - loss: 0.4966 - accuracy: 0.7658 - val_loss: 0.5197 - val_accuracy: 0.7430
# Epoch 36/50
# 177/177 [==============================] - 2s 11ms/step - loss: 0.5104 - accuracy: 0.7576 - val_loss: 0.4945 - val_accuracy: 0.7669
# Epoch 37/50
# 177/177 [==============================] - 2s 11ms/step - loss: 0.4919 - accuracy: 0.7695 - val_loss: 0.5050 - val_accuracy: 0.7674
# Epoch 38/50
# 177/177 [==============================] - 2s 11ms/step - loss: 0.4904 - accuracy: 0.7721 - val_loss: 0.5217 - val_accuracy: 0.7700
# Epoch 39/50
# 177/177 [==============================] - 2s 11ms/step - loss: 0.4940 - accuracy: 0.7668 - val_loss: 0.5200 - val_accuracy: 0.7610
# Epoch 40/50
# 177/177 [==============================] - 2s 11ms/step - loss: 0.5034 - accuracy: 0.7652 - val_loss: 0.4885 - val_accuracy: 0.7711
# Epoch 41/50
# 177/177 [==============================] - 2s 11ms/step - loss: 0.5068 - accuracy: 0.7589 - val_loss: 0.4947 - val_accuracy: 0.7716
# Epoch 42/50
# 177/177 [==============================] - 2s 11ms/step - loss: 0.4953 - accuracy: 0.7711 - val_loss: 0.5258 - val_accuracy: 0.7552
# Epoch 43/50
# 177/177 [==============================] - 2s 11ms/step - loss: 0.5095 - accuracy: 0.7642 - val_loss: 0.5914 - val_accuracy: 0.7403
# Epoch 44/50
# 177/177 [==============================] - 2s 11ms/step - loss: 0.5043 - accuracy: 0.7590 - val_loss: 0.5208 - val_accuracy: 0.7605
# Epoch 45/50
# 177/177 [==============================] - 2s 11ms/step - loss: 0.4790 - accuracy: 0.7796 - val_loss: 0.4887 - val_accuracy: 0.7631
# Epoch 46/50
# 177/177 [==============================] - 2s 11ms/step - loss: 0.4892 - accuracy: 0.7725 - val_loss: 0.5166 - val_accuracy: 0.7748
# Epoch 47/50
# 177/177 [==============================] - 2s 11ms/step - loss: 0.4841 - accuracy: 0.7753 - val_loss: 0.4749 - val_accuracy: 0.7754
# Epoch 48/50
# 177/177 [==============================] - 2s 11ms/step - loss: 0.4847 - accuracy: 0.7797 - val_loss: 0.4902 - val_accuracy: 0.7754
# Epoch 49/50
# 177/177 [==============================] - 2s 11ms/step - loss: 0.4791 - accuracy: 0.7849 - val_loss: 0.4719 - val_accuracy: 0.7785
# Epoch 50/50
# 177/177 [==============================] - 2s 11ms/step - loss: 0.4803 - accuracy: 0.7739 - val_loss: 0.4740 - val_accuracy: 0.7828

# %% [markdown]
# Nous allons visualiser les deux métriques: l'erreur et la précision, par époque, lors de l'entraînement du modèle pour avoir une meilleure idée de la façon dont l'entraînement s'est déroulé.

# %%
fig, axs = plt.subplots(1, 2, figsize=(20, 5))

axs[0].set_title('Loss')
axs[0].plot(history1.history['loss'], label='train')
axs[0].plot(history1.history['val_loss'], label='val')
axs[0].legend()

axs[1].set_title('Accuracy')
axs[1].plot(history1.history['accuracy'], label='train')
axs[1].plot(history1.history['val_accuracy'], label='val')
axs[1].legend()

# %% [markdown]
# ### LSTM
#
# Nous allons tester un autre modèle en utilisant le type de Réseaux de neurones LSTM. L'usage de LSTM est très efficace pour exécuter des taches de NLP.
#
# Un réseau LSTM est organisé de manière similaire à un RNN, mais deux états sont transmis d'une couche à l'autre : l'état réel et le vecteur caché. À chaque unité, le vecteur caché est combiné à l'entrée , et ensemble, ils contrôlent ce qui arrive à l'état et à la sortie par le biais de portes. Chaque porte a une activation sigmoïde (sortie dans la plage), qui peut être considérée comme un masque bit à bit lorsqu'elle est multipliée par le vecteur d'état. Les LSTMs ont alors les trois portes.
#
# Notons que La ligne horizontale dans le schéma suivant correspond à la propagation quasi à l'identique du vecteur d'état de cellule (_cell state_), ce qui assure la propagation de l'information initiale.
#
# ![LSTM1.jpg](attachment:LSTM1.jpg)
#
# Quel est le nom et le fonctionnement de ces différents portes  ?
#
# <blockquote>
# <strong style="text-decoration:underline;display:block">Solution</strong>
#
# <ul>
#     <li>La porte 1 est appelée <em>forget gate layer</em>, ou porte d'oubli, elle détermine les composantes du vecteur que nous devons oublier, et celles qui doivent passer.</li>
#     <li>La porte 2 est appelée <em>input gate layer</em>, ou porte d'entrée, elle détermine la quantité d'informations du vecteur d'entrée et du vecteur caché précédent à incorporer dans le vecteur d'état.</li>
#     <li>La porte 3 est appelée <em>output gate</em>, ou porte de sortie, elle prend le nouveau vecteur d'état et décide lesquelles de ses composantes seront utilisées pour produire le nouveau vecteur caché.</li>
# </ul>
#
# Ce sont ces portes qui contrôlent le flux d'informations nécessaire pour prédire la sortie dans le réseau.
# </blockquote>
#
# Vous trouverez des explications plus détaillées de cette architecture [ici](https://larevueia.fr/quest-ce-quun-reseau-lstm/).

# %% [markdown]
# Pour les scénarios qui nécessitent un accès aléatoire à la séquence d'entrée, il est plus logique d'exécuter le calcul récurrent dans les deux sens. Les RNN qui permettent des calculs dans les deux sens sont appelés RNN <em>bidirectionnels</em>, et ils peuvent être créés en enveloppant la couche récurrente d'une couche bidirectonale spéciale.
#
# La couche bidirectionnelle fait deux copies de la couche qu'il contient, et définit la propriété `go_backwards` de l'une de ces copies à <code class="cm-s-ipython language-python"><span class="cm-keyword">True</span></code>, la faisant aller dans la direction opposée le long de la séquence.
# Les réseaux récurrents, unidirectionnels ou bidirectionnels, capturent des patterns dans une séquence, et les stockent dans des vecteurs d'état ou les renvoient en sortie. Comme pour les réseaux convolutifs, nous pouvons construire une autre couche récurrente à la suite de la première pour capturer des patterns de plus haut niveau, construits à partir de patterns de plus bas niveau extraits par la première couche. Cela nous conduit à la notion de RNN multicouche, qui consiste en deux réseaux récurrents ou plus, où la sortie de la couche précédente est transmise à la couche suivante comme entrée.
# ![image.png](attachment:image.png)
#                                 Figure faite par Fernando López.
#
# Construisons un LSTM bidirectionnel à une couche cachée avec 128 neurones et dropout égal à 0.3.

# %%
model2 = tf.keras.Sequential([
    embedding,
    tf.keras.layers.SpatialDropout1D(0.4),
    # LSTM bidirectionnel à une couche cachée avec 128 neurones et dropout égal à 0.3
    tf.keras.layers.Bidirectional(tf.keras.layers.LSTM(128, dropout=0.3)) #SOLUTION
    , tf.keras.layers.Dense(1, activation='sigmoid')
])

model2.compile(
    # fonction de loss binary cross entropy
    loss=\
    tf.keras.losses.BinaryCrossentropy(from_logits=True) #SOLUTION
    , optimizer=tf.keras.optimizers.Adam(0.01), 
    # accuracy metric
    metrics=['accuracy'] ) #SOLUTION

history2 = model2.fit( tf_data,  validation_data = tf_val_data, epochs = 50   ) 

fig, axs = plt.subplots(1, 2, figsize=(20, 5))

axs[0].set_title('Loss')
axs[0].plot(history2.history['loss'], label='train')
axs[0].plot(history2.history['val_loss'], label='val')
axs[0].legend()

axs[1].set_title('Accuracy')
# Représentation de l'accuracy pour data train en axe 2
axs[1].plot(history2.history['accuracy'], label='train') #SOLUTION
# Représentation de l'accuracy pour data val en axe 2
axs[1].plot(history2.history['val_accuracy'], label='val') #SOLUTION
axs[1].legend()
# Out:
# Epoch 1/50
# 177/177 [==============================] - 6s 20ms/step - loss: 0.5341 - accuracy: 0.7454 - val_loss: 0.5108 - val_accuracy: 0.7573
# Epoch 2/50
# 177/177 [==============================] - 3s 16ms/step - loss: 0.4814 - accuracy: 0.7748 - val_loss: 0.4956 - val_accuracy: 0.7971
# Epoch 3/50
# 177/177 [==============================] - 3s 16ms/step - loss: 0.5026 - accuracy: 0.7661 - val_loss: 0.4351 - val_accuracy: 0.8109
# Epoch 4/50
# 177/177 [==============================] - 3s 16ms/step - loss: 0.4795 - accuracy: 0.7808 - val_loss: 0.4491 - val_accuracy: 0.7971
# Epoch 5/50
# 177/177 [==============================] - 3s 16ms/step - loss: 0.4627 - accuracy: 0.7895 - val_loss: 0.4775 - val_accuracy: 0.7876
# Epoch 6/50
# 177/177 [==============================] - 3s 16ms/step - loss: 0.4439 - accuracy: 0.8015 - val_loss: 0.4559 - val_accuracy: 0.7982
# Epoch 7/50
# 177/177 [==============================] - 3s 16ms/step - loss: 0.4383 - accuracy: 0.8045 - val_loss: 0.4368 - val_accuracy: 0.8040
# Epoch 8/50
# 177/177 [==============================] - 3s 16ms/step - loss: 0.4357 - accuracy: 0.8031 - val_loss: 0.4731 - val_accuracy: 0.7966
# Epoch 9/50
# 177/177 [==============================] - 3s 16ms/step - loss: 0.4413 - accuracy: 0.7987 - val_loss: 0.4426 - val_accuracy: 0.8056
# Epoch 10/50
# 177/177 [==============================] - 3s 16ms/step - loss: 0.4288 - accuracy: 0.8059 - val_loss: 0.4472 - val_accuracy: 0.8008
# Epoch 11/50
# 177/177 [==============================] - 3s 16ms/step - loss: 0.4255 - accuracy: 0.8065 - val_loss: 0.4395 - val_accuracy: 0.8109
# Epoch 12/50
# 177/177 [==============================] - 3s 17ms/step - loss: 0.4249 - accuracy: 0.8036 - val_loss: 0.4526 - val_accuracy: 0.8046
# Epoch 13/50
# 177/177 [==============================] - 3s 17ms/step - loss: 0.4207 - accuracy: 0.8075 - val_loss: 0.4499 - val_accuracy: 0.8062
# Epoch 14/50
# 177/177 [==============================] - 3s 17ms/step - loss: 0.4184 - accuracy: 0.8067 - val_loss: 0.4628 - val_accuracy: 0.8030
# Epoch 15/50
# 177/177 [==============================] - 3s 16ms/step - loss: 0.4090 - accuracy: 0.8153 - val_loss: 0.4563 - val_accuracy: 0.8008
# Epoch 16/50
# 177/177 [==============================] - 3s 16ms/step - loss: 0.4169 - accuracy: 0.8125 - val_loss: 0.4516 - val_accuracy: 0.8003
# Epoch 17/50
# 177/177 [==============================] - 3s 16ms/step - loss: 0.4161 - accuracy: 0.8116 - val_loss: 0.4530 - val_accuracy: 0.8046
# Epoch 18/50
# 177/177 [==============================] - 3s 16ms/step - loss: 0.4246 - accuracy: 0.8065 - val_loss: 0.4533 - val_accuracy: 0.8035
# Epoch 19/50
# 177/177 [==============================] - 3s 16ms/step - loss: 0.4250 - accuracy: 0.8038 - val_loss: 0.4432 - val_accuracy: 0.8024
# Epoch 20/50
# 177/177 [==============================] - 3s 16ms/step - loss: 0.4124 - accuracy: 0.8134 - val_loss: 0.4492 - val_accuracy: 0.8040
# Epoch 21/50
# 177/177 [==============================] - 3s 17ms/step - loss: 0.4148 - accuracy: 0.8098 - val_loss: 0.4395 - val_accuracy: 0.8035
# Epoch 22/50
# 177/177 [==============================] - 3s 17ms/step - loss: 0.4166 - accuracy: 0.8162 - val_loss: 0.4540 - val_accuracy: 0.8136
# Epoch 23/50
# 177/177 [==============================] - 3s 16ms/step - loss: 0.4168 - accuracy: 0.8111 - val_loss: 0.4567 - val_accuracy: 0.8040
# Epoch 24/50
# 177/177 [==============================] - 3s 16ms/step - loss: 0.4067 - accuracy: 0.8192 - val_loss: 0.4620 - val_accuracy: 0.8008
# Epoch 25/50
# 177/177 [==============================] - 3s 16ms/step - loss: 0.4166 - accuracy: 0.8143 - val_loss: 0.4652 - val_accuracy: 0.7945
# Epoch 26/50
# 177/177 [==============================] - 3s 16ms/step - loss: 0.4250 - accuracy: 0.8107 - val_loss: 0.4577 - val_accuracy: 0.8046
# Epoch 27/50
# 177/177 [==============================] - 3s 16ms/step - loss: 0.4126 - accuracy: 0.8148 - val_loss: 0.4442 - val_accuracy: 0.8035
# Epoch 28/50
# 177/177 [==============================] - 3s 16ms/step - loss: 0.4129 - accuracy: 0.8141 - val_loss: 0.4558 - val_accuracy: 0.8014
# Epoch 29/50
# 177/177 [==============================] - 3s 16ms/step - loss: 0.4023 - accuracy: 0.8182 - val_loss: 0.4495 - val_accuracy: 0.7913
# Epoch 30/50
# 177/177 [==============================] - 3s 16ms/step - loss: 0.4069 - accuracy: 0.8176 - val_loss: 0.4651 - val_accuracy: 0.8046
# Epoch 31/50
# 177/177 [==============================] - 3s 16ms/step - loss: 0.4186 - accuracy: 0.8102 - val_loss: 0.4453 - val_accuracy: 0.8099
# Epoch 32/50
# 177/177 [==============================] - 3s 17ms/step - loss: 0.4145 - accuracy: 0.8123 - val_loss: 0.4560 - val_accuracy: 0.8104
# Epoch 33/50
# 177/177 [==============================] - 3s 17ms/step - loss: 0.4101 - accuracy: 0.8150 - val_loss: 0.4560 - val_accuracy: 0.8056
# Epoch 34/50
# 177/177 [==============================] - 3s 17ms/step - loss: 0.4256 - accuracy: 0.8070 - val_loss: 0.4559 - val_accuracy: 0.7987
# Epoch 35/50
# 177/177 [==============================] - 3s 17ms/step - loss: 0.4518 - accuracy: 0.7967 - val_loss: 0.4473 - val_accuracy: 0.8093
# Epoch 36/50
# 177/177 [==============================] - 3s 17ms/step - loss: 0.4461 - accuracy: 0.7959 - val_loss: 0.4614 - val_accuracy: 0.7945
# Epoch 37/50
# 177/177 [==============================] - 3s 17ms/step - loss: 0.4517 - accuracy: 0.7937 - val_loss: 0.4569 - val_accuracy: 0.8120
# Epoch 38/50
# 177/177 [==============================] - 3s 16ms/step - loss: 0.4446 - accuracy: 0.7959 - val_loss: 0.4625 - val_accuracy: 0.8030
# Epoch 39/50
# 177/177 [==============================] - 3s 17ms/step - loss: 0.4369 - accuracy: 0.7990 - val_loss: 0.4596 - val_accuracy: 0.8040
# Epoch 40/50
# 177/177 [==============================] - 3s 16ms/step - loss: 0.4355 - accuracy: 0.8031 - val_loss: 0.4788 - val_accuracy: 0.8035
# Epoch 41/50
# 177/177 [==============================] - 3s 16ms/step - loss: 0.4343 - accuracy: 0.8026 - val_loss: 0.4502 - val_accuracy: 0.8051
# Epoch 42/50
# 177/177 [==============================] - 3s 17ms/step - loss: 0.4398 - accuracy: 0.7950 - val_loss: 0.4497 - val_accuracy: 0.8014
# Epoch 43/50
# 177/177 [==============================] - 3s 16ms/step - loss: 0.4417 - accuracy: 0.8035 - val_loss: 0.4509 - val_accuracy: 0.8051
# Epoch 44/50
# 177/177 [==============================] - 3s 16ms/step - loss: 0.4386 - accuracy: 0.8079 - val_loss: 0.4375 - val_accuracy: 0.8120
# Epoch 45/50
# 177/177 [==============================] - 3s 16ms/step - loss: 0.4327 - accuracy: 0.8042 - val_loss: 0.4520 - val_accuracy: 0.8051
# Epoch 46/50
# 177/177 [==============================] - 3s 16ms/step - loss: 0.4355 - accuracy: 0.7999 - val_loss: 0.4762 - val_accuracy: 0.7945
# Epoch 47/50
# 177/177 [==============================] - 3s 16ms/step - loss: 0.4308 - accuracy: 0.8058 - val_loss: 0.4555 - val_accuracy: 0.8014
# Epoch 48/50
# 177/177 [==============================] - 3s 16ms/step - loss: 0.4338 - accuracy: 0.7973 - val_loss: 0.4618 - val_accuracy: 0.8003
# Epoch 49/50
# 177/177 [==============================] - 3s 16ms/step - loss: 0.4405 - accuracy: 0.7966 - val_loss: 0.4539 - val_accuracy: 0.8003
# Epoch 50/50
# 177/177 [==============================] - 3s 16ms/step - loss: 0.4441 - accuracy: 0.7932 - val_loss: 0.4556 - val_accuracy: 0.8051

# %% [markdown]
# Comparez les résultats trouvés par LSTM à ceux de GRU. Que peut-on en conclure ?
#
# <blockquote>
# Les résultats montrent que la différence entre les valeurs de précision pour les ensembles d'apprentissage et de validation est beaucoup plus faible par rapport au LSTM qu'au GRU. De même, la différence entre les valeurs de perte est également négligeable, ce qui montre que notre modèle n'est pas surajusté.
#     </blockquote>

# %% [markdown]
# ## Évaluation des performances des modèles
#
# On sait maintenant quelle architecture est la plus adaptée, mais il est intéressant de comprendre pourquoi. Voyons quelles sont les phrases que nos deux modèles ont mal interprété. Pour ce faire, les modèles doivent produire des prédictions pour l'ensemble de données. Cela implique un pipeline légèrement différent.

# %%
prediction1 = model1.predict(tf_val_data)
prediction1 = np.concatenate(prediction1).round().astype(int)
dtest['prediction1'] = prediction1

prediction2 = model2.predict(tf_val_data)
prediction2 = np.concatenate(prediction2).round().astype(int)
dtest['prediction2'] = prediction2
# Out:
# 1/1 [==============================] - 0s 333ms/step
# 1/1 [==============================] - 1s 784ms/step

# %% [markdown]
# ### Evaluation des modèles par le dataset test
#
# Jetons un coup d'œil aux résultats du modèle 1 et du modèle 2 pour nous faire une idée de leurs performances. La méthode d'évaluation la plus rapide et la plus simple consiste à examiner les métriques produites par le modèle. Les métriques finales peuvent être extraites à l'aide de la méthode `evaluate` sur le jeu de données de validation.

# %%
# Evaluation du modèle  GRU sur la partie test
score1=model1.evaluate(dtest['prediction1'],dtest['target'],verbose=1)

print("Validation Score model1:", score1[0])
print("Validation Accuracy model1:", score1[1])
# Out:
# 59/59 [==============================] - 1s 1ms/step - loss: 0.7077 - accuracy: 0.5720
# Validation Score model1: 0.707683801651001
# Validation Accuracy model1: 0.5719596147537231

# %% [markdown]
# Affichez l'évaluation du modèle LSTM sur la partie de test. Il nous faut la valeur de l'erreur de la validation ainsi que l'accuracy ou la précision.

# %%
# Evaluation du modèle LSTM sur la partie test
score2 =\
    model2.evaluate(dtest['prediction2'],dtest['target'],verbose=1) #SOLUTION

# Affichage de l'erreur: Validation Score model1 et de l'accuracy du modèle 2: Validation Accuracy model2
print(\
      "Validation Score model2:", score2[0]) #SOLUTION
print(\
      "Validation Accuracy model2:", score2[1]) #SOLUTION
# Out:
# 59/59 [==============================] - 1s 1ms/step - loss: 0.7265 - accuracy: 0.5720
# Validation Score model2: 0.7264774441719055
# Validation Accuracy model2: 0.5719596147537231

# %% [markdown]
# Que pensez-vous de ces valeurs ? Qu'en concluez-vous ?
#
# <blockquote>
# <strong style="text-decoration:underline;display:block">Solution</strong>
#
# L'accuracy sur les données test est plus élevée avec LSTM qu'avec GRU. De même, l'erreur est également plus faible avec LSTM qu'avec GRU. Nous pouvons conclure que, pour notre problème, le LSTM est plus performant que le GRU, avec une différence importante.
#
# Notons cependant que GRU utilise moins de paramètres d'apprentissage et donc moins de mémoire et s'exécute plus rapidement que LSTM alors que LSTM est plus précis sur un plus grand ensemble de données.
#
# On peut choisir LSTM si l'on a affaire à de grandes séquences et que la précision est importante, mais GRU est préférable lorsque l'on veut des résultats plus rapides, et/ou qu'on doit fonctionner avec moins de mémoire.
#
# Pour votre projet final, il est préférable de tester les différents réseaux neuronaux et de choisir le plus efficace en fonction de vos données d'entraînement.
#
# </blockquote>

# %% [markdown]
# Essayons maintenant de rentrer un peu plus dans le détail des performances de cette architecture.
#
# ### Évaluation des résultats du LSTM
# Commençons par examiner les faux positifs. À quelle situation ces faux positifs correspondent-ils ?
#
# <blockquote>
# <strong style="text-decoration:underline;display:block">Solution</strong>
# Au cas où le modèle a trouvé qu'il y a une catastrophe évoquée dans le tweet mais qu'il n'y en a pas.
# </blockquote>
# Comptons donc ces faux positifs, et jetons un coup d'oeil aux 10 premiers tweets.

# %%
false_positives =\
    dtest[(dtest['prediction2'] == 1) & (dtest['target'] == 0)] #SOLUTION

print('Count of false positives: ' + str(len(false_positives)))

false_positives.head(10)
# Out:
# Count of false positives: 149
#                                                    text  target  prediction1  \
# 5624  viralspell couple spend wedding day feeding  s...       0            0
# 3155  the eye nation broader conservation community ...       0            1
# 4428  who tomislav salopek islamic states most recen...       0            1
# 4441  wtf her biological father holding hostage adop...       0            0
# 4863  theeconomist step one get mass murderers portr...       0            0
# 4618  clearedincident injuryi inner loop exit georgi...       0            0
# 2020    lmao fuckboy changed damage control pseudojuuzo       0            0
# 624                             fight bioterrorism sir.       0            0
# 5006  pakistan supreme court oks military courts try...       0            1
# 3675                bardissimo yes life  fatality rate.       0            0
#
#       prediction2
# 5624            1
# 3155            1
# 4428            1
# 4441            1
# 4863            1
# 4618            1
# 2020            1
# 624             1
# 5006            1
# 3675            1

# %% [markdown]
# Ensuite, il faut faire la même chose avec les faux négatifs. À quel comportement du réseau correspondent-ils ?
#
# <blockquote>
# <strong style="text-decoration:underline;display:block">Solution</strong>
# Au cas où le modèle a trouvé qu'il y n'avait pas de catastrophe évoquée dans un tweet alors qu'en fait, il y en avait une.</blockquote>

# %%
false_negatives =\
    dtest[(dtest['prediction2'] == 0) & (dtest['target'] == 1)] #SOLUTION

print('Count of false negatives: ' + str(len(false_negatives)))

false_positives.tail(10)
# Out:
# Count of false negatives: 218
#                                                    text  target  prediction1  \
# 4019  who bringing tornado floods. who bringing clim...       0            1
# 4983  hat russian soviet army kgb military cossack u...       0            0
# 1628  åèmgnafricaå¨ pin correction tent collapse sto...       0            0
# 595   thank fedex longer shipping live microbe depar...       0            0
# 1973  his majesty emperor salman khans unstoppable c...       0            0
# 7545  late night mcdonalds friend hilarious although...       0            0
# 5746  rascal flatts riot tour atlantic city beach co...       0            0
# 7057  usw the damage abandoning deal could well crea...       0            1
# 3645  motordom lobbied change language around traffi...       0            0
# 3738  morganite gemstone white fire opal  sterling s...       0            0
#
#       prediction2
# 4019            1
# 4983            1
# 1628            1
# 595             1
# 1973            1
# 7545            1
# 5746            1
# 7057            1
# 3645            1
# 3738            1

# %% [markdown]
# Une fois que le modèle est entraîné, il ne reste plus que quelques étapes à franchir pour charger les données de test et utiliser le modèle pour étiqueter les phrases de test comme désastre ou non. Tout d'abord, convertissez les données en un ensemble de données TensorFlow et appliquez les méthodes du pipeline. Le pipeline a été légèrement ajusté pour tenir compte du fait que l'on ne veut pas de shuffling et de la forme différente de l'entrée (sans étiquette).

# %%
tf_test_data = tf.data.Dataset.from_tensor_slices((encoded_test_sentences))


def test_pipeline(tf_data, batch_size=1):        
    tf_data = tf_data.prefetch(tf.data.experimental.AUTOTUNE)
    tf_data = tf_data.padded_batch(batch_size, padded_shapes=([None]))
    
    return tf_data

tf_test_data = test_pipeline(tf_test_data)

print(len(tf_test_data))

# Utiliser le modèle pour étiqueter les phrases des données test comme désastre ou non
predictions = model2.predict(tf_test_data)

predictions = np.concatenate(predictions).round().astype(int)
# Out:
# 3263
# 3263/3263 [==============================] - 5s 1ms/step

# %% [markdown]
# Soumettez les phrases des données du dataset test et sauvegardez la soumission dans un fichier CSV pour pouvoir classer chaque tweet avec une catastrophe évoquée ou non.

# %%
submission =\
    pd.DataFrame(data={'target': predictions}, index=test_data_c['id']) #SOLUTION
submission.index =\
    submission.index.rename('id') #SOLUTION
submission.to_csv('submission.csv')


submission.head()
# Out:
#     target
# id
# 0        1
# 2        1
# 3        1
# 9        1
# 11       1

# %% [markdown]
# Suite à cette étude nous avons pu prévoir l'analyse des sentiments des tweets par RNN.
#
#
# ### Pour aller plus loin avec NLP
#
# Les ensembles de données d'apprentissage, de validation et de test sont susceptibles de contenir des mots que les autres ensembles de données ne contiennent pas. Si le modèle n'est entraîné que sur les mots de l'ensemble de données d'entraînement, il peut y avoir un problème d'overfitting lorsque le modèle essaie de lire des mots qu'il ne reconnaît pas dans les ensembles de données de validation et de test.
#
# La question qui se pose, c'est _à quel point ce problème est-il présent ?_
# La fonction ci-dessous prend deux ensembles de données et compte la façon dont les mots correspondent et ne correspondent pas, elle nous permettra de nous faire une idée.

# %%
def compare_words(train_words, test_words):
    unique_words = len(np.union1d(train_words, test_words)) 
    matching =\
        len(np.intersect1d(train_words, test_words)) #SOLUTION
    not_in_train = len(np.setdiff1d(test_words, train_words)) 
    not_in_test = len(np.setdiff1d(train_words, test_words))
    
    print('Nombre de mots dans les deux parties dtrain et dtest: ' + str(unique_words))
    print('Nombre de mots en concordance: ' + str(matching))
    print('Nombre de mots dans le dataset dtrain et non dans le dataset test: ' + str(not_in_test))
    print('Nombre de mots dans le dataset test et non pas dans le dataset dtrain: ' + str(not_in_train))

# Comparaison entre les données d'apprentissage et les données validation
compare_words(encoded_sentences, val_encoded_sentences)
# Out:
# Nombre de mots dans les deux parties dtrain et dtest: 15954
# Nombre de mots en concordance: 4050
# Nombre de mots dans le dataset dtrain et non dans le dataset test: 9335
# Nombre de mots dans le dataset test et non pas dans le dataset dtrain: 2569

# %% [markdown]
# Cela montre que seulement 25 % des mots se trouvent dans les deux ensembles de données et que l'ensemble de données utilisé pour la validation contient 16 % des mots qui ne se trouvent pas dans l'ensemble de données utilisé pour l'entraînement. Manifestement, cela affecte négativement les performances du modèle.

# %%
# Comparaison entre les données d'apprentissage et les données test
compare_words(encoded_sentences, encoded_test_sentences)
# Out:
# Nombre de mots dans les deux parties dtrain et dtest: 17844
# Nombre de mots en concordance: 5095
# Nombre de mots dans le dataset dtrain et non dans le dataset test: 8290
# Nombre de mots dans le dataset test et non pas dans le dataset dtrain: 4459

# %% [markdown]
# 28 % se trouvent dans les deux datasets.
# 47% se trouvent dans le dataset d'entraînement et pas dans le dataset de test
# 25 % se trouvent dans le dataset de test et pas dans le dataset d'entraînement.
#
# Nous pouvons utiliser l'approche basée sur les règles lexiques (https://datapeaker.com/fr/Big-Data/analyse-des-sentiments-bas%C3%A9e-sur-des-r%C3%A8gles-en-python-pour-les-scientifiques-des-donn%C3%A9es/). Ces simples approches largement utilisées en NLP sont TextBlob, VADER, SentiWordNet. Elles recherchent les mots d'opinion dans un texte et les classer ensuite en fonction du nombre de mots annonçant une catastophe ou non.

# %% [markdown]
# # Conclusion
#
# Bravo, Vous venez de réaliser votre premier travail d'analyse du traitement de langage naturel ou NLP ! Vous avez effectuer une analyse des Tweets en utilisant les réseaux de neurones récurrents GRU et LSTM.
#
# Vous avez vu comment nettoyer les corpus, visualiser les résultats des Twitters puis vous avez pu implémenter, entraîner et évaluer les RNN ainsi qu'améliorer ses performances en essayant GRU et LSTM. Félicitations !
#
# Mais il vous reste à améliorer la performance du modèle. Tout d'abord, la précision n'est que de 79.3% . Évidemment, augmenter la taille du réseau va nettement impacter la rapidité de l'apprentissage. Il existe sûrement d'autres approches pour améliorer les résultats. Ici dans l'étape de Word embedding, nous avons utilisé GloVe, un algorithme d'apprentissage non supervisé qui fait correspondre les mots dans un espace où la similarité sémantique entre les mots est observée par la distance entre les mots. D'autres techniques de word embedding telles que Word2vec ou Se2seq, peuvent être utilisées. Il existe également des architectures prétraitées, appelées Transformer, que vous pouvez utiliser, telles que BERT(Devlin et al., 2018), et GPT-2 (de Radford et al 2019). Pour approfondir vos connaissances sur ces approches, vous pouvez consulter le site ce [lien](https://france.devoteam.com/paroles-dexperts/lstm-transformers-gpt-bert-guide-des-principales-techniques-en-nlp/).
